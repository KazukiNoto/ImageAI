# %%
from io import open
import requests
import shutil
from zipfile import ZipFile
import os
from imageai.Prediction.Custom import ModelTraining

execution_path = os.getcwd()

TRAIN_ZIP_ONE = os.path.join(execution_path, "idenprof-train1.zip")
TRAIN_ZIP_TWO = os.path.join(execution_path, "idenprof-train2.zip")
TEST_ZIP = os.path.join(execution_path, "idenprof-test.zip")

DATASET_DIR = os.path.join(execution_path, "idenprof")
DATASET_TRAIN_DIR = os.path.join(DATASET_DIR, "train")
DATASET_TEST_DIR = os.path.join(DATASET_DIR, "test")
if(os.path.exists(DATASET_DIR) == False):
    os.mkdir(DATASET_DIR)
if(os.path.exists(DATASET_TRAIN_DIR) == False):
    os.mkdir(DATASET_TRAIN_DIR)
if(os.path.exists(DATASET_TEST_DIR) == False):
    os.mkdir(DATASET_TEST_DIR)

# %%
if(len(os.listdir(DATASET_TRAIN_DIR)) < 10):
    if(os.path.exists(TRAIN_ZIP_ONE) == False):
        print("Downloading idenprof-train1.zip")
        data = requests.get("https://github.com/OlafenwaMoses/IdenProf/releases/download/v1.0/idenprof-train1.zip", stream = True)
        with open(TRAIN_ZIP_ONE, "wb") as file:
            shutil.copyfileobj(data.raw, file)
        del data
    if (os.path.exists(TRAIN_ZIP_TWO) == False):
        print("Downloading idenprof-train2.zip")
        data = requests.get("https://github.com/OlafenwaMoses/IdenProf/releases/download/v1.0/idenprof-train2.zip", stream=True)
        with open(TRAIN_ZIP_TWO, "wb") as file:
            shutil.copyfileobj(data.raw, file)
        del data
    print("Extracting idenprof-train1.zip")
    extract1 = ZipFile(TRAIN_ZIP_ONE)
    extract1.extractall(DATASET_TRAIN_DIR)
    extract1.close()
    print("Extracting idenprof-train2.zip")
    extract2 = ZipFile(TRAIN_ZIP_TWO)
    extract2.extractall(DATASET_TRAIN_DIR)
    extract2.close()
# Out:
# Extracting idenprof-train1.zip
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-3-f73769002a4a> in <module>
#      13         del data
#      14     print("Extracting idenprof-train1.zip")
# ---> 15     extract1 = ZipFile(TRAIN_ZIP_ONE)
#      16     extract1.extractall(DATASET_TRAIN_DIR)
#      17     extract1.close()
#
# /usr/local/lib/python3.5/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1024         try:
#    1025             if mode == 'r':
# -> 1026                 self._RealGetContents()
#    1027             elif mode in ('w', 'x'):
#    1028                 # set the modified flag so central directory gets written
#
# /usr/local/lib/python3.5/zipfile.py in _RealGetContents(self)
#    1091             raise BadZipFile("File is not a zip file")
#    1092         if not endrec:
# -> 1093             raise BadZipFile("File is not a zip file")
#    1094         if self.debug > 1:
#    1095             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
if(len(os.listdir(DATASET_TEST_DIR)) < 10):
    if (os.path.exists(TEST_ZIP) == False):
        print("Downloading idenprof-test.zip")
        data = requests.get("https://github.com/OlafenwaMoses/IdenProf/releases/download/v1.0/idenprof-test.zip", stream=True)
        with open(TEST_ZIP, "wb") as file:
            shutil.copyfileobj(data.raw, file)
        del data
    print("Extracting idenprof-test.zip")
    extract = ZipFile(TEST_ZIP)
    extract.extractall(DATASET_TEST_DIR)
    extract.close()
# Out:
# Extracting idenprof-test.zip
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-4-d746dbeff24c> in <module>
#       7         del data
#       8     print("Extracting idenprof-test.zip")
# ----> 9     extract = ZipFile(TEST_ZIP)
#      10     extract.extractall(DATASET_TEST_DIR)
#      11     extract.close()
#
# /usr/local/lib/python3.5/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1024         try:
#    1025             if mode == 'r':
# -> 1026                 self._RealGetContents()
#    1027             elif mode in ('w', 'x'):
#    1028                 # set the modified flag so central directory gets written
#
# /usr/local/lib/python3.5/zipfile.py in _RealGetContents(self)
#    1091             raise BadZipFile("File is not a zip file")
#    1092         if not endrec:
# -> 1093             raise BadZipFile("File is not a zip file")
#    1094         if self.debug > 1:
#    1095             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
model_trainer = ModelTraining()
model_trainer.setModelTypeAsResNet()
model_trainer.setDataDirectory(DATASET_DIR)
# model_trainer.trainModel(num_objects=10, num_experiments=40, enhance_data=True, batch_size=8, show_network_summary=True)
model_trainer.trainModel(num_objects=4, num_experiments=100, enhance_data=True, batch_size=32, show_network_summary=True)
# Out:
# ________________
# conv2d_238 (Conv2D)             (None, 14, 14, 256)  590080      activation_222[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_238 (Bat (None, 14, 14, 256)  1024        conv2d_238[0][0]
# __________________________________________________________________________________________________
# activation_223 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_238[0][0]
# __________________________________________________________________________________________________
# conv2d_239 (Conv2D)             (None, 14, 14, 1024) 263168      activation_223[0][0]
# __________________________________________________________________________________________________
# conv2d_236 (Conv2D)             (None, 14, 14, 1024) 525312      activation_221[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_239 (Bat (None, 14, 14, 1024) 4096        conv2d_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_236 (Bat (None, 14, 14, 1024) 4096        conv2d_236[0][0]
# __________________________________________________________________________________________________
# add_71 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_v1_239[0][0]
#                                                                  batch_normalization_v1_236[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 14, 14, 1024) 0           add_71[0][0]
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 14, 14, 256)  262400      activation_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_240 (Bat (None, 14, 14, 256)  1024        conv2d_240[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_240[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 14, 14, 256)  590080      activation_225[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_241 (Bat (None, 14, 14, 256)  1024        conv2d_241[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_241[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 14, 14, 1024) 263168      activation_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_242 (Bat (None, 14, 14, 1024) 4096        conv2d_242[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_v1_242[0][0]
#                                                                  activation_224[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 14, 14, 1024) 0           add_72[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 14, 14, 256)  262400      activation_227[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_243 (Bat (None, 14, 14, 256)  1024        conv2d_243[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_243[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 14, 14, 256)  590080      activation_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_244 (Bat (None, 14, 14, 256)  1024        conv2d_244[0][0]
# __________________________________________________________________________________________________
# activation_229 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_244[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 14, 14, 1024) 263168      activation_229[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_245 (Bat (None, 14, 14, 1024) 4096        conv2d_245[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_v1_245[0][0]
#                                                                  activation_227[0][0]
# __________________________________________________________________________________________________
# activation_230 (Activation)     (None, 14, 14, 1024) 0           add_73[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 14, 14, 256)  262400      activation_230[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_246 (Bat (None, 14, 14, 256)  1024        conv2d_246[0][0]
# __________________________________________________________________________________________________
# activation_231 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_246[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 14, 14, 256)  590080      activation_231[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_247 (Bat (None, 14, 14, 256)  1024        conv2d_247[0][0]
# __________________________________________________________________________________________________
# activation_232 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_247[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 14, 14, 1024) 263168      activation_232[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_248 (Bat (None, 14, 14, 1024) 4096        conv2d_248[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_v1_248[0][0]
#                                                                  activation_230[0][0]
# __________________________________________________________________________________________________
# activation_233 (Activation)     (None, 14, 14, 1024) 0           add_74[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 14, 14, 256)  262400      activation_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_249 (Bat (None, 14, 14, 256)  1024        conv2d_249[0][0]
# __________________________________________________________________________________________________
# activation_234 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_249[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 14, 14, 256)  590080      activation_234[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_250 (Bat (None, 14, 14, 256)  1024        conv2d_250[0][0]
# __________________________________________________________________________________________________
# activation_235 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_250[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 14, 14, 1024) 263168      activation_235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_251 (Bat (None, 14, 14, 1024) 4096        conv2d_251[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_v1_251[0][0]
#                                                                  activation_233[0][0]
# __________________________________________________________________________________________________
# activation_236 (Activation)     (None, 14, 14, 1024) 0           add_75[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 14, 14, 256)  262400      activation_236[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_252 (Bat (None, 14, 14, 256)  1024        conv2d_252[0][0]
# __________________________________________________________________________________________________
# activation_237 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_252[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 14, 14, 256)  590080      activation_237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_253 (Bat (None, 14, 14, 256)  1024        conv2d_253[0][0]
# __________________________________________________________________________________________________
# activation_238 (Activation)     (None, 14, 14, 256)  0           batch_normalization_v1_253[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 14, 14, 1024) 263168      activation_238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_254 (Bat (None, 14, 14, 1024) 4096        conv2d_254[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, 14, 14, 1024) 0           batch_normalization_v1_254[0][0]
#                                                                  activation_236[0][0]
# __________________________________________________________________________________________________
# activation_239 (Activation)     (None, 14, 14, 1024) 0           add_76[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 7, 7, 512)    524800      activation_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_256 (Bat (None, 7, 7, 512)    2048        conv2d_256[0][0]
# __________________________________________________________________________________________________
# activation_240 (Activation)     (None, 7, 7, 512)    0           batch_normalization_v1_256[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 7, 7, 512)    2359808     activation_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_257 (Bat (None, 7, 7, 512)    2048        conv2d_257[0][0]
# __________________________________________________________________________________________________
# activation_241 (Activation)     (None, 7, 7, 512)    0           batch_normalization_v1_257[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 7, 7, 2048)   1050624     activation_241[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 7, 7, 2048)   2099200     activation_239[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_258 (Bat (None, 7, 7, 2048)   8192        conv2d_258[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_255 (Bat (None, 7, 7, 2048)   8192        conv2d_255[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_v1_258[0][0]
#                                                                  batch_normalization_v1_255[0][0]
# __________________________________________________________________________________________________
# activation_242 (Activation)     (None, 7, 7, 2048)   0           add_77[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 7, 7, 512)    1049088     activation_242[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_259 (Bat (None, 7, 7, 512)    2048        conv2d_259[0][0]
# __________________________________________________________________________________________________
# activation_243 (Activation)     (None, 7, 7, 512)    0           batch_normalization_v1_259[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 7, 7, 512)    2359808     activation_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_260 (Bat (None, 7, 7, 512)    2048        conv2d_260[0][0]
# __________________________________________________________________________________________________
# activation_244 (Activation)     (None, 7, 7, 512)    0           batch_normalization_v1_260[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 7, 7, 2048)   1050624     activation_244[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_261 (Bat (None, 7, 7, 2048)   8192        conv2d_261[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_v1_261[0][0]
#                                                                  activation_242[0][0]
# __________________________________________________________________________________________________
# activation_245 (Activation)     (None, 7, 7, 2048)   0           add_78[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 7, 7, 512)    1049088     activation_245[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_262 (Bat (None, 7, 7, 512)    2048        conv2d_262[0][0]
# __________________________________________________________________________________________________
# activation_246 (Activation)     (None, 7, 7, 512)    0           batch_normalization_v1_262[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 7, 7, 512)    2359808     activation_246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_263 (Bat (None, 7, 7, 512)    2048        conv2d_263[0][0]
# __________________________________________________________________________________________________
# activation_247 (Activation)     (None, 7, 7, 512)    0           batch_normalization_v1_263[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 7, 7, 2048)   1050624     activation_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_v1_264 (Bat (None, 7, 7, 2048)   8192        conv2d_264[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_v1_264[0][0]
#                                                                  activation_245[0][0]
# __________________________________________________________________________________________________
# activation_248 (Activation)     (None, 7, 7, 2048)   0           add_79[0][0]
# __________________________________________________________________________________________________
# global_avg_pooling (GlobalAvera (None, 2048)         0           activation_248[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 4)            8196        global_avg_pooling[0][0]
# __________________________________________________________________________________________________
# activation_249 (Activation)     (None, 4)            0           dense_4[0][0]
# ==================================================================================================
# Total params: 23,595,908
# Trainable params: 23,542,788
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Using Enhanced Data Generation
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# JSON Mapping for the model classes saved to  /workspaces/ImageAI/Tutorial/02_CustomePredictionModelTraining/idenprof/json/model_class.json
# Number of experiments (Epochs) :  100
# Epoch 1/100
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-b46719c61e0f> in <module>
#       3 model_trainer.setDataDirectory(DATASET_DIR)
#       4 # model_trainer.trainModel(num_objects=10, num_experiments=40, enhance_data=True, batch_size=8, show_network_summary=True)
# ----> 5 model_trainer.trainModel(num_objects=4, num_experiments=100, enhance_data=True, batch_size=32, show_network_summary=True)
#
# /usr/local/lib/python3.5/site-packages/imageai/Prediction/Custom/__init__.py in trainModel(self, num_objects, num_experiments, enhance_data, batch_size, initial_learning_rate, show_network_summary, training_image_size, continue_from_model, transfer_from_model, transfer_with_full_training, initial_num_objects, save_full_model)
#     340         model.fit_generator(train_generator, steps_per_epoch=int(num_train / batch_size), epochs=self.__num_epochs,
#     341                             validation_data=test_generator,
# --> 342                             validation_steps=int(num_test / batch_size), callbacks=[checkpoint, lr_scheduler, tensorboard])
#     343
#     344
#
# /usr/local/lib/python3.5/site-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1424         use_multiprocessing=use_multiprocessing,
#    1425         shuffle=shuffle,
# -> 1426         initial_epoch=initial_epoch)
#    1427
#    1428   def evaluate_generator(self,
#
# /usr/local/lib/python3.5/site-packages/tensorflow/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, **kwargs)
#     206         break
#     207
# --> 208     aggregator.finalize()
#     209     results = aggregator.results
#     210     epoch_logs.update(training_utils.make_logs(model, results, mode))
#
# /usr/local/lib/python3.5/site-packages/tensorflow/python/keras/engine/training_utils.py in finalize(self)
#     106
#     107   def finalize(self):
# --> 108     self.results[0] /= self.num_samples_or_steps
#     109
#     110
#
# IndexError: list index out of range
