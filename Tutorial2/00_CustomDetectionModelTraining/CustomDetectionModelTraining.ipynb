# %%
from imageai.Detection.Custom import DetectionModelTrainer

trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory="NorinoHasamiyaki")
trainer.setTrainConfig(object_names_array=["NorinoHasamiyaki"], batch_size=4, num_experiments=1)
# In the above,when training for detecting multiple objects,
#set object_names_array=["object1", "object2", "object3",..."objectz"]
trainer.trainModel()
# Out:
# Using TensorFlow backend.
# Generating anchor boxes for training images and annotation...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-741cebdd3943> in <module>
#       4 trainer.setModelTypeAsYOLOv3()
#       5 trainer.setDataDirectory(data_directory="storeItem")
# ----> 6 trainer.setTrainConfig(object_names_array=["storeItem"], batch_size=4, num_experiments=200)
#       7 # In the above,when training for detecting multiple objects,
#       8 #set object_names_array=["object1", "object2", "object3",..."objectz"]
#
# /usr/local/lib/python3.5/site-packages/imageai/Detection/Custom/__init__.py in setTrainConfig(self, object_names_array, batch_size, num_experiments, train_from_pretrained_model)
#     169         self.__model_anchors, self.__inference_anchors = generateAnchors(self.__train_annotations_folder,
#     170                                                                           self.__train_images_folder,
# --> 171                                                                           self.__train_cache_file, self.__model_labels)
#     172
#     173         self.__model_labels = sorted(object_names_array)
#
# /usr/local/lib/python3.5/site-packages/imageai/Detection/Custom/gen_anchors.py in generateAnchors(train_annotation_folder, train_image_folder, train_cache_file, model_labels)
#      93
#      94     annotation_dims = np.array(annotation_dims)
# ---> 95     centroids = run_kmeans(annotation_dims, num_anchors)
#      96
#      97     # write anchors to file
#
# /usr/local/lib/python3.5/site-packages/imageai/Detection/Custom/gen_anchors.py in run_kmeans(ann_dims, anchor_num)
#      42     old_distances = np.zeros((ann_num, anchor_num))
#      43
# ---> 44     indices = [random.randrange(ann_dims.shape[0]) for i in range(anchor_num)]
#      45     centroids = ann_dims[indices]
#      46     anchor_dim = ann_dims.shape[1]
#
# /usr/local/lib/python3.5/site-packages/imageai/Detection/Custom/gen_anchors.py in <listcomp>(.0)
#      42     old_distances = np.zeros((ann_num, anchor_num))
#      43
# ---> 44     indices = [random.randrange(ann_dims.shape[0]) for i in range(anchor_num)]
#      45     centroids = ann_dims[indices]
#      46     anchor_dim = ann_dims.shape[1]
#
# /usr/local/lib/python3.5/random.py in randrange(self, start, stop, step, _int)
#     193             if istart > 0:
#     194                 return self._randbelow(istart)
# --> 195             raise ValueError("empty range for randrange()")
#     196
#     197         # stop argument supplied.
#
# ValueError: empty range for randrange()
